# %% [markdown]
# # Chapter 2 · Cart Pole
#
# CartPole uses **numbers**, not grid squares. Too big for a table → use a small **neural network** (**DQN**).
#
# This is what we ran at **MindBubble** in 2019 (updated for Gymnasium).

# %%
# !python -m workshop.cartpole_dqn --max-runs 150

# %% [markdown]
# Chart: `output/cartpole/scores.png`. Look for the rolling average approaching **195**.
#
# Optional: `!python -m workshop.cartpole_dqn --render --max-runs 30` to watch learning live.
