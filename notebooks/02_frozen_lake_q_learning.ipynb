# %% [markdown]
# # Chapter 1 · Frozen Lake
#
# ## The Icy Grid
#
# You are crossing a frozen pond. **Green** = safe. **Holes** = restart. Goal = reach the flag.
#
# Algorithm: **Q-Learning** — a table of best moves for each square.

# %%
# !python -m workshop.q_learning --env FrozenLake-v1 --algorithm q_learning --episodes 3000

# %% [markdown]
# Open the chart in `output/tabular/q_learning_frozenlake_v1.png`. Average reward should climb as the table fills in.
#
# **Coach question:** What if we gave +100 for moving right even when there is a hole that way?
