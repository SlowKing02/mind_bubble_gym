# %% [markdown]
# # Chapter 3 · Mountain Car
#
# The car is stuck in a valley. The engine cannot climb straight up — you must **swing** to build speed.
#
# Algorithm: **PPO** (policy gradient). Industry default for many control problems today.

# %%
# !python -m workshop.ppo_demo --env MountainCar-v0 --timesteps 60000

# %% [markdown]
# PPO learns a policy: given position and speed, which way to push?
#
# Compare to DQN: here we learn the **dance**, not just score each foot position.
